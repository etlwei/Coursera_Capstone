# %% [markdown]
# # Segmenting and Clustering Neighborhoods in Toronto -- PART 2

# %% [markdown]
# ### Preparations (PART 1)

# %%
from requests import get       # import the get function from requests module
url="https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
response = get(url)            # retrieve HTML file from the given Wikipedia URL

from bs4 import BeautifulSoup                       # import the "beautifulsoup4" library
soup=BeautifulSoup(response.text,"html.parser")     # make the soup, the format convenient for both extracting and preprocessing of the data
table = soup.find("tbody")    # find the table data and save as "table"

import pandas as pd
data=[]                                          # create an empty dataset "data"

rows = table.find_all('tr')                      # find all rows in the "table" 
for row in rows:                                 # use for loop to read each entry of the "Wikitable" to the "data"
    cols = row.find_all('td')               
    cols = [ele.text.strip() for ele in cols]
    data.append([ele for ele in cols if ele])

df=pd.DataFrame(data)                            # create the dataframe requried using "Pandas"


df.columns=["PostalCode","Borough","Neighborhood"]   # Rename the columns as required

for i in df.index:                         # use the for loop to find all rows with their "Borough" values to be "Not Assigned"
    if df.iloc[i,1]=="Not assigned":       #
        df.iloc[i,1]=None                  # replace the "Not Assigned" to "None", which can be droped using dropna()

df.dropna(inplace=True)                 # remove all rows with "None" values
df.reset_index(drop=True,inplace=True)     # reset the index

for j in df.index:                      # use the for loop to find the all rows with their "Neighborhood" values to be "Not Assigned"                
    if df.iloc[j,2]=="Not assigned":    #       
        df.iloc[j,2]=df.iloc[j,1]       # set their neighborhood to be equivalent to their "Borgough" values
        

pd.options.mode.chained_assignment = None               # avoid the warn of chained assignment, default='warn'

for k in range(1,212):                                  # use for loop to combine the rows with the same "Borough" values
    if df.iloc[k-1,1]==df.iloc[k,1]:                    # if i-1th and ith row share the same borough
        df.iloc[k,2]=df.iloc[k-1,2]+","+df.iloc[k,2]    # append i-1th neighborhood to ith neighborhood separated with ","
        df.iloc[k-1,2]=None                             # set the i-1th neighborhood to "None" in order to remove by dropna later

df.dropna(inplace=True)                                 # drop all the rows with "None" values
df.reset_index(drop=True,inplace=True)                  # reset the index

print(df.shape)
df.head()
# Out:
# (85, 3)
#   PostalCode           Borough                     Neighborhood
# 0        M4A        North York       Parkwoods,Victoria Village
# 1        M5A  Downtown Toronto         Harbourfront,Regent Park
# 2        M6A        North York  Lawrence Heights,Lawrence Manor
# 3        M7A      Queen's Park                     Queen's Park
# 4        M9A         Etobicoke                 Islington Avenue

# %%
##############################################################################################################

# %% [markdown]
# ### Building the Dataframe with Latitude and Longitude Data

# %% [markdown]
# Since the `Geocoder` does not work well here, we will use the `CSV` file instead.

# %%
latlng=pd.read_csv("https://cocl.us/Geospatial_data")    # read the online CSV file into pandas dataframe
latlng.head()                                            # check the dataframe
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# After retrieving the `latlng` dataframe, now it is time to build the new dataframe by updating latitude and longtitude data. We will use pandas's built-in `.merge()` method to do the **Inner-Join** of two dataframes.

# %%
df_latlng=df.merge(latlng,left_on="PostalCode",right_on="Postal Code")    # inner join two dataframes, "df" as left set and "latlng" as right set, keyword is the Postal Code from both sets                                                       #
print(df_latlng.shape)                                                    #
df_latlng.head()                                                          # checked the merged dataframe "df_latlng"
# Out:
# (85, 6)
#   PostalCode           Borough                     Neighborhood Postal Code  \
# 0        M4A        North York       Parkwoods,Victoria Village         M4A
# 1        M5A  Downtown Toronto         Harbourfront,Regent Park         M5A
# 2        M6A        North York  Lawrence Heights,Lawrence Manor         M6A
# 3        M7A      Queen's Park                     Queen's Park         M7A
# 4        M9A         Etobicoke                 Islington Avenue         M9A
#
#     Latitude  Longitude
# 0  43.725882 -79.315572
# 1  43.654260 -79.360636
# 2  43.718518 -79.464763
# 3  43.662301 -79.389494
# 4  43.667856 -79.532242

# %% [markdown]
# Since the order of the columns changes, here we rearrange the order and get the final dataframe.

# %%
df_latlng=df_latlng[["Postal Code","Borough","Neighborhood","Latitude","Longitude"]]    # rearrange the order by recalling each columns in required order

# %%
df_latlng    # The final datafram with latitude and longitude
# Out:
#    Postal Code           Borough  \
# 0          M4A        North York
# 1          M5A  Downtown Toronto
# 2          M6A        North York
# 3          M7A      Queen's Park
# 4          M9A         Etobicoke
# 5          M1B       Scarborough
# 6          M3B        North York
# 7          M4B         East York
# 8          M5B  Downtown Toronto
# 9          M6B        North York
# 10         M9B         Etobicoke
# 11         M1C       Scarborough
# 12         M3C        North York
# 13         M4C         East York
# 14         M5C  Downtown Toronto
# 15         M6C              York
# 16         M9C         Etobicoke
# 17         M1E       Scarborough
# 18         M4E      East Toronto
# 19         M5E  Downtown Toronto
# 20         M6E              York
# 21         M1G       Scarborough
# 22         M4G         East York
# 23         M6G  Downtown Toronto
# 24         M1H       Scarborough
# 25         M3H        North York
# 26         M4H         East York
# 27         M5H  Downtown Toronto
# 28         M6H      West Toronto
# 29         M1J       Scarborough
# ..         ...               ...
# 55         M2P        North York
# 56         M5P   Central Toronto
# 57         M6P      West Toronto
# 58         M9P         Etobicoke
# 59         M1R       Scarborough
# 60         M2R        North York
# 61         M5R   Central Toronto
# 62         M6R      West Toronto
# 63         M7R       Mississauga
# 64         M9R         Etobicoke
# 65         M1S       Scarborough
# 66         M4S   Central Toronto
# 67         M5S  Downtown Toronto
# 68         M6S      West Toronto
# 69         M1T       Scarborough
# 70         M4T   Central Toronto
# 71         M5T  Downtown Toronto
# 72         M1V       Scarborough
# 73         M4V   Central Toronto
# 74         M5V  Downtown Toronto
# 75         M9V         Etobicoke
# 76         M1W       Scarborough
# 77         M5W  Downtown Toronto
# 78         M9W         Etobicoke
# 79         M1X       Scarborough
# 80         M5X  Downtown Toronto
# 81         M8X         Etobicoke
# 82         M4Y  Downtown Toronto
# 83         M7Y      East Toronto
# 84         M8Z         Etobicoke
#
#                                          Neighborhood   Latitude  Longitude
# 0                          Parkwoods,Victoria Village  43.725882 -79.315572
# 1                            Harbourfront,Regent Park  43.654260 -79.360636
# 2                     Lawrence Heights,Lawrence Manor  43.718518 -79.464763
# 3                                        Queen's Park  43.662301 -79.389494
# 4                                    Islington Avenue  43.667856 -79.532242
# 5                                       Rouge,Malvern  43.806686 -79.194353
# 6                                     Don Mills North  43.745906 -79.352188
# 7                      Woodbine Gardens,Parkview Hill  43.706397 -79.309937
# 8                             Ryerson,Garden District  43.657162 -79.378937
# 9                                           Glencairn  43.709577 -79.445073
# 10  Cloverdale,Islington,Martin Grove,Princess Gar...  43.650943 -79.554724
# 11               Highland Creek,Rouge Hill,Port Union  43.784535 -79.160497
# 12                    Flemingdon Park,Don Mills South  43.725900 -79.340923
# 13                                   Woodbine Heights  43.695344 -79.318389
# 14                                     St. James Town  43.651494 -79.375418
# 15                                 Humewood-Cedarvale  43.693781 -79.428191
# 16  Bloordale Gardens,Eringate,Markland Wood,Old B...  43.643515 -79.577201
# 17                    Guildwood,Morningside,West Hill  43.763573 -79.188711
# 18                                        The Beaches  43.676357 -79.293031
# 19                                        Berczy Park  43.644771 -79.373306
# 20                                Caledonia-Fairbanks  43.689026 -79.453512
# 21                                             Woburn  43.770992 -79.216917
# 22                                            Leaside  43.709060 -79.363452
# 23                        Central Bay Street,Christie  43.669542 -79.422564
# 24                                          Cedarbrae  43.773136 -79.239476
# 25  Hillcrest Village,Bathurst Manor,Downsview Nor...  43.754328 -79.442259
# 26                                   Thorncliffe Park  43.705369 -79.349372
# 27                             Adelaide,King,Richmond  43.650571 -79.384568
# 28                        Dovercourt Village,Dufferin  43.669005 -79.442259
# 29                                Scarborough Village  43.744734 -79.239476
# ..                                                ...        ...        ...
# 55                                    York Mills West  43.752758 -79.400049
# 56  Davisville North,Forest Hill North,Forest Hill...  43.696948 -79.411307
# 57                       High Park,The Junction South  43.661608 -79.464763
# 58                                          Westmount  43.696319 -79.532242
# 59                                   Maryvale,Wexford  43.750072 -79.295849
# 60                                    Willowdale West  43.782736 -79.442259
# 61  North Toronto West,The Annex,North Midtown,Yor...  43.672710 -79.405678
# 62                              Parkdale,Roncesvalles  43.648960 -79.456325
# 63              Canada Post Gateway Processing Centre  43.636966 -79.615819
# 64  Kingsview Village,Martin Grove Gardens,Richvie...  43.688905 -79.554724
# 65                                          Agincourt  43.794200 -79.262029
# 66                                         Davisville  43.704324 -79.388790
# 67                      Harbord,University of Toronto  43.662696 -79.400049
# 68                                  Runnymede,Swansea  43.651571 -79.484450
# 69              Clarks Corners,Sullivan,Tam O'Shanter  43.781638 -79.304302
# 70                         Moore Park,Summerhill East  43.689574 -79.383160
# 71            Chinatown,Grange Park,Kensington Market  43.653206 -79.400049
# 72  Agincourt North,L'Amoreaux East,Milliken,Steel...  43.815252 -79.284577
# 73  Deer Park,Forest Hill SE,Rathnelly,South Hill,...  43.686412 -79.400049
# 74  CN Tower,Bathurst Quay,Island airport,Harbourf...  43.628947 -79.394420
# 75  Humber Bay Shores,Mimico South,New Toronto,Alb...  43.739416 -79.588437
# 76                       L'Amoreaux West,Steeles West  43.799525 -79.318389
# 77           Rosedale,Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 78                    Alderwood,Long Branch,Northwest  43.706748 -79.594054
# 79                                        Upper Rouge  43.836125 -79.205636
# 80  Cabbagetown,St. James Town,First Canadian Plac...  43.648429 -79.382280
# 81        The Kingsway,Montgomery Road,Old Mill North  43.653654 -79.506944
# 82                               Church and Wellesley  43.665860 -79.383160
# 83   Business reply mail Processing Centre969 Eastern  43.662744 -79.321558
# 84  Humber Bay,King's Mill Park,Kingsway Park Sout...  43.628841 -79.520999
#
# [85 rows x 5 columns]
